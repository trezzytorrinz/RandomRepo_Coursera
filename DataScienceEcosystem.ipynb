# %% [markdown]
# ## __Data Science Tools and Ecosystem__

# %% [markdown]
# ![2-title.png](attachment:6943020c-a16a-453d-8676-01f599ee41be.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ![3-intro.png](attachment:fe32cd88-ccf0-464c-9730-cceff0debbd8.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL
# 4. Ruby

# %% [markdown]
# ![4-dslanguages.png](attachment:9c0dac6a-750e-4054-9771-e0c4afff55c6.png)

# %% [markdown]
# Some of the commonly used by Data Scientists include:
#
# 1. Numpy
# 2. Keras
# 3. Pandas

# %% [markdown]
# ![5-dslibraries.png](attachment:c568c356-7cd7-4686-83e4-2ec855619f37.png)

# %% [markdown]
# |Data Science Tools|
# |---|
# |Weka|
# |Pandas|
# |Scrapy|

# %% [markdown]
# ![6-dstools.png](attachment:8e9fbf5a-3e22-4229-907f-5d2e50dc576b.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# ![7-introarithmetic.png](attachment:34e303c6-0024-47c0-a809-949a7d412ba4.png)

# %%
# This is a simple arithmetic expression to multiply then add integers.
(3 * 4) + 5
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:878afd6a-8f77-4308-a92c-4a38ec4e7c4c.png)

# %%
# This will convert 200 minutes to hours by dividing by 60.
200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# ![9-hourstominutes.png](attachment:bd3fd744-8f5d-4a38-b38f-069b62fbef84.png)

# %% [markdown]
# __Objectives:__
#
# - Python
# - Ruby
# - SQL

# %% [markdown]
# ![10-objectives.png](attachment:ccc91beb-ff14-4c01-8a0e-e36d955fa569.png)

# %% [markdown]
# ## Author
#
# Tremendes Roper

# %% [markdown]
# ![11-authordetails.png](attachment:161e8773-9f6a-44f4-8dcd-9aff9ab706d1.png)
